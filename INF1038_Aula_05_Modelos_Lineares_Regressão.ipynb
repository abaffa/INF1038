# %% [markdown]
# # Gerando Dados p/ Exemplo bidimensional simples

# %% [markdown]
# $y = x + 2 + \eta$

# %%
import numpy as np

X = np.arange(-5, 5, 0.05)

nb_samples = len(X)

Y = X + 2
Y += np.random.normal(0.0, 2, size=nb_samples)

# %%
import matplotlib.pyplot as plt

plt.scatter(X, Y)
plt.show()

# %% [markdown]
# ### Função de Perda
#
# $ 𝐿=\frac{1}{2} \sum_{𝑖=1}^m (\alpha + \beta x_i + y_i)^2$
#
#
# ### Gradiente
# $\Biggl\{
# \begin{array}{ll}
#  \frac{\delta L}{\delta \alpha} \sum_{𝑖=1}^n (\alpha + \beta x_i - y_i) = 0\\
#  \frac{\delta L}{\delta \beta} \sum_{𝑖=1}^n (\alpha + \beta x_i - y_i)x_i = 0
# \end{array}$

# %%
def loss(v):
   e = 0.0
   for i in range(nb_samples):
      e += np.square(v[0] + v[1]*X[i] - Y[i])
   return 0.5 * e


def gradient(v):
   g = np.zeros(shape=2)
   for i in range(nb_samples):
      g[0] += (v[0] + v[1]*X[i] - Y[i])
      g[1] += ((v[0] + v[1]*X[i] - Y[i]) * X[i])
   return g

# %% [markdown]
# ### Minimizar

# %%
from scipy.optimize import minimize
res = minimize(fun=loss, x0=[0.0, 0.0], jac=gradient, method='L-BFGS-B')
res
# Out:
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 420.1132533563985
#         x: [ 2.146e+00  1.033e+00]
#       nit: 8
#       jac: [ 5.961e-06 -4.680e-05]
#      nfev: 9
#      njev: 9
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>

# %%
def predictY(X, alpha, beta):
    Ym = []
    for i in range(len(X)):
        Ym.append(beta * X[i] + alpha)
    return Ym

# %%
Ym = predictY(X, res.x[0], res.x[1])

from sklearn.metrics import r2_score
r2 = r2_score(Y,Ym)
print('r2 score for perfect model is', r2)
# Out:
# r2 score for perfect model is 0.6792031616754616

# %%
import matplotlib.pyplot as plt

alpha =  res.x[0]
beta = res.x[1]

Ym = predictY(X, alpha, beta)

plt.scatter(X, Y)
plt.plot(X, Ym, color="red", linewidth=3)
plt.show()

# %% [markdown]
# ## Método Matricial

# %%
Xs = np.expand_dims(X, axis=1)
Ys = np.expand_dims(Y, axis=1)
Xs = np.concatenate((Xs, np.ones_like(Xs)), axis=1)

result = np.linalg.inv(np.dot(Xs.T, Xs)).dot(Xs.T).dot(Y)
print(result[1], result[0])
print('y = %2.f + %.2fx' % (result[1], result[0]))
# Out:
# 2.0365228569465863 1.01660561568203
# y =  2 + 1.02x

# %%
result
# Out:
# array([1.01660562, 2.03652286])

# %%
Ym = predictY(X, result[1], result[0])

from sklearn.metrics import r2_score
r2 = r2_score(Y,Ym)
print('r2 score for perfect model is', r2)
# Out:
# r2 score for perfect model is 0.964667389727995

# %%
import matplotlib.pyplot as plt

alpha = result[1]
beta = result[0]

Ym = predictY(X, alpha, beta)

plt.scatter(X, Y)
plt.plot(X, Ym, color="red", linewidth=3)
plt.show()

# %% [markdown]
# ## Exemplo de Regressão

# %%
import pandas as pd  # doctest: +SKIP
import numpy as np

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)

boston={}
boston["data"] = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
boston["target"] = raw_df.values[1::2, 2]

# %%
print(boston["data"].shape)

print(boston["target"].shape)
# Out:
# (506, 13)
# (506,)

# %%
def norma_l2(X):
    X = X - np.mean(X, axis=0)
    X = X / np.linalg.norm(X, axis=0)
    return X

# %%
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(boston["data"], boston["target"], test_size=0.3)

lr = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
reg = lr.fit(X_train, Y_train)

# %%
print(reg['linearregression'].coef_)
print(reg['linearregression'].intercept_)
print(reg.score(X_test, Y_test))
# Out:
# [-0.3479886   1.17446251  0.34576962  0.76600329 -1.60200821  3.49682573
#  -0.29648572 -2.91345831  1.99204477 -1.75368029 -1.95646004  0.69111307
#  -3.30844083]
# 25.275655900340816
# 0.6476268292047325

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(lr, boston["data"], boston["target"], cv=7, scoring='neg_mean_squared_error')
scores
# Out:
# array([ -11.30795492,  -10.94743251,  -32.12487323,  -33.57836799,
#         -10.54825524, -149.57087382,  -12.93285837])

# %%
print(scores.mean())
print(scores.std())
# Out:
# -37.287230868353085
# 46.78955638801992

# %%
scores = cross_val_score(lr, boston["data"], boston["target"], cv=7, scoring='r2')
scores
# Out:
# array([ 0.6534446 ,  0.59631685,  0.67865382,  0.61193393,  0.51940514,
#        -0.30577687,  0.4001835 ])

# %%
print(scores.mean())
print(scores.std())
# Out:
# 0.45059442471362726
# 0.3206685989502157

# %% [markdown]
# ## Variância Explicada

# %% [markdown]
# $EV = 1-\frac{Var[Y-\tilde{Y}]}{Var[Y]}$

# %%
print(cross_val_score(lr, boston["data"], boston["target"], cv=7, scoring='explained_variance'))
# Out:
# [ 0.66521666  0.62517506  0.71074827  0.61741337  0.57297245 -0.15926251
#   0.49621415]

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge

lr = LinearRegression()
rg = Ridge(0.05)

lr_scores = cross_val_score(lr,  norma_l2(boston["data"]), boston["target"], cv=7)
print(lr_scores)
print(lr_scores.mean())


rg_scores = cross_val_score(rg,  norma_l2(boston["data"]), boston["target"], cv=7)
print(rg_scores)
print(rg_scores.mean())
# Out:
# [ 0.6534446   0.59631685  0.67865382  0.61193393  0.51940514 -0.30577687
#   0.4001835 ]
# 0.4505944247136278
# [ 0.72006099  0.6417548   0.66042987  0.61092785  0.56271438 -0.11567796
#   0.47999145]
# 0.5086001970190454

# %%
from sklearn.linear_model import RidgeCV

rg = RidgeCV(alphas=(1.0, 0.1, 0.01, 0.05, 0.005, 0.0025, 0.001, 0.00025),cv=7)
rg.fit(norma_l2(boston["data"]), boston["target"])

print(rg.alpha_)
# Out:
# 0.1

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso

ls = Lasso(alpha=0.01)

ls_scores = cross_val_score(ls, norma_l2(boston["data"]), boston["target"], cv=7)

print(ls_scores.mean())
# Out:
# 0.4575355812078458

# %%
from sklearn.linear_model import LassoCV

rs = LassoCV(alphas=(1.0, 0.1, 0.01, 0.005, 0.0025, 0.001, 0.00025),cv=7)
rs.fit(norma_l2(boston["data"]), boston["target"])

print(rs.alpha_)
# Out:
# 0.001

# %% [markdown]
# ## ElasticNet Regression

# %%
from sklearn.linear_model import ElasticNet, ElasticNetCV

en = ElasticNet(alpha=0.001, l1_ratio=0.8)
en_scores = cross_val_score(en, norma_l2(boston["data"]), boston["target"], cv=7)

print(en_scores.mean())
# Out:
# 0.5184128742552574

# %%
encv = ElasticNetCV(alphas=(0.1, 0.01,0.05, 0.005, 0.0025, 0.001), l1_ratio=(0.1, 0.25, 0.5, 0.75, 0.8),cv=7)
encv.fit(norma_l2(boston["data"]), boston["target"])

print(encv.alpha_)
print(encv.l1_ratio_)
# Out:
# 0.001
# 0.5

# %% [markdown]
# ## RANSAC

# %%
import numpy as np

X1 = np.arange(-5, 2.5, 0.05)

X2 = np.arange(2.5, 5, 0.05)

X = np.concatenate((X1, X2))

Y1 = X1 + 2
Y1 += np.random.normal(0.0, 0.5, size=len(X1))

Y2 = X2 + 10
Y2 += np.random.normal(0.0, 1, size=len(X2))

Y = np.concatenate((Y1, Y2))

# %%
import matplotlib.pyplot as plt

plt.scatter(X, Y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X.reshape((-1, 1)), Y.reshape((-1, 1)))

print(lr.intercept_)

print(lr.coef_)
# Out:
# [3.96669443]
# [[1.89106917]]

# %%
import matplotlib.pyplot as plt

alpha =  lr.intercept_[0]
beta = lr.coef_[0][0]

Ym = predictY(X, alpha, beta)

plt.scatter(X, Y)
plt.plot(X, Ym, color="red", linewidth=3)
plt.show()

# %%
from sklearn.linear_model import RANSACRegressor

rs = RANSACRegressor(lr)
rs.fit(X.reshape((-1, 1)), Y.reshape((-1, 1)))

print(rs.estimator_.intercept_)
print(rs.estimator_.coef_)
# Out:
# [1.97902729]
# [[1.00620149]]

# %%
import matplotlib.pyplot as plt

alpha =  rs.estimator_.intercept_[0]
beta = rs.estimator_.coef_[0][0]

Ym = predictY(X, alpha, beta)

plt.scatter(X, Y)
plt.plot(X, Ym, color="red", linewidth=3)
plt.show()

# %% [markdown]
# ## Huber Regression

# %%
import matplotlib.pyplot as plt

alpha =  rs.estimator_.intercept_[0]
beta = rs.estimator_.coef_[0][0]

Ym = predictY(X, alpha, beta)

plt.scatter(X, Y)
plt.plot(X, Ym, color="red", linewidth=3)
plt.show()

# %%
import numpy as np
from random import random, randint

X = np.arange(-5, 5, 0.05)

Y = X + 2

Y += np.random.normal(0.0, 0.5, size=len(X))

for i in range(0,len(Y)):
    if random() > 0.7:
        Y[i] += randint(0,10)

# %%
import matplotlib.pyplot as plt

plt.scatter(X, Y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X.reshape((-1, 1)), Y.reshape((-1, 1)))

print(lr.intercept_)

print(lr.coef_)
# Out:
# [3.63378292]
# [[1.0704462]]

# %%
import matplotlib.pyplot as plt

alpha =  lr.intercept_[0]
beta = lr.coef_[0][0]

Ym = predictY(X, alpha, beta)

plt.scatter(X, Y)
plt.plot(X, Ym, color="red", linewidth=3)
plt.show()

# %% [markdown]
# #### Vamos comparar o resultado com o Ransac

# %%
from sklearn.linear_model import RANSACRegressor

rs = RANSACRegressor(lr)
rs.fit(X.reshape((-1, 1)), Y.reshape((-1, 1)))

print(rs.estimator_.intercept_)
print(rs.estimator_.coef_)
# Out:
# [2.24567241]
# [[1.04150497]]

# %%
import matplotlib.pyplot as plt

alpha =  rs.estimator_.intercept_[0]
beta = rs.estimator_.coef_[0][0]

Ym = predictY(X, alpha, beta)

plt.scatter(X, Y)
plt.plot(X, Ym, color="red", linewidth=3)
plt.show()

# %%
#### ... mas e se eu modificar o parâmetro tH do Huber e definir um limite?

# %%
from sklearn.linear_model import HuberRegressor

hr = HuberRegressor(epsilon=1.25) # epsilon do sklearn é o tH
hr.fit(X.reshape(-1, 1), Y)

print(hr.intercept_)
print(hr.coef_)
# Out:
# 2.350289773143591
# [1.03061189]

# %%
import matplotlib.pyplot as plt

alpha =  hr.intercept_
beta = hr.coef_[0]

Ym = predictY(X, alpha, beta)

plt.scatter(X, Y)
plt.plot(X, Ym, color="red", linewidth=3)
plt.show()

# %% [markdown]
# ## Polinomial Regression

# %%
import numpy as np

X = np.arange(-5, 5, 0.05)

nb_samples = len(X)

Y = X**2 + 2
Y += np.random.normal(0.0, 0.5, size=nb_samples)

# %%
import matplotlib.pyplot as plt

plt.scatter(X, Y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X.reshape((-1, 1)), Y.reshape((-1, 1)))

print(lr.score(X.reshape((-1, 1)), Y.reshape((-1, 1))))

print(lr.intercept_)
print(lr.coef_)
# Out:
# 0.0005662811171323057
# [10.26593703]
# [[-0.06114219]]

# %%
import matplotlib.pyplot as plt

alpha =  lr.intercept_
beta = lr.coef_[0]

Ym = predictY(X, alpha, beta)

plt.scatter(X, Y)
plt.plot(X, Ym, color="red", linewidth=3)
plt.show()

# %%
def predictYpolinomial(X, alpha, beta):
    Ym = []
    print(len(beta))
    for i in range(len(X)):
        y = alpha
        for c in range(1, len(beta)):
            y += beta[c] * (X[i]**c)
        Ym.append(y)

    return Ym

# %%
from sklearn.preprocessing import PolynomialFeatures

pf = PolynomialFeatures(degree=2)
Xp = pf.fit_transform(X.reshape(-1, 1))

lr.fit(Xp, Y.reshape((-1, 1)))

print(lr.score(Xp, Y.reshape((-1, 1))))
print(lr.intercept_)
print(lr.coef_)
# Out:
# 0.9952399998275043
# [1.99589078]
# [[ 0.         -0.01151695  0.9925048 ]]

# %%
import matplotlib.pyplot as plt

alpha =  lr.intercept_[0]

Ym = predictYpolinomial(X, alpha, lr.coef_[0])

plt.scatter(X, Y)
plt.plot(X, Ym, color="red", linewidth=3)
plt.show()
# Out:
# 3

# %% [markdown]
# ### Grau 3

# %%
import numpy as np

X = np.arange(-5, 5, 0.05)

nb_samples = len(X)

Y = 2*(X**3) + 0.5*(X**2) + X + 2
Y += np.random.normal(0.0, 0.5, size=nb_samples)

# %%
import matplotlib.pyplot as plt

plt.scatter(X, Y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X.reshape((-1, 1)), Y.reshape((-1, 1)))

print(lr.score(X.reshape((-1, 1)), Y.reshape((-1, 1))))

print(lr.intercept_)
print(lr.coef_)
# Out:
# 0.847543095731875
# [5.74308327]
# [[30.96545342]]

# %%
import matplotlib.pyplot as plt

alpha =  lr.intercept_
beta = lr.coef_[0]

Ym = predictY(X, alpha, beta)

plt.scatter(X, Y)
plt.plot(X, Ym, color="red", linewidth=3)
plt.show()

# %%
from sklearn.metrics import r2_score

r2 = r2_score(Y,Ym)
print('r2 score for perfect model is', r2)
# Out:
# r2 score for perfect model is 0.847543095731875

# %%
from sklearn.preprocessing import PolynomialFeatures

pf = PolynomialFeatures(degree=3)
Xp = pf.fit_transform(X.reshape(-1, 1))

lr.fit(Xp, Y.reshape((-1, 1)))

print(lr.score(Xp, Y.reshape((-1, 1))))
print(lr.intercept_)
print(lr.coef_)
# Out:
# 0.9999696376300696
# [2.07866672]
# [[0.         0.96585589 0.49981914 2.0015058 ]]

# %%
import matplotlib.pyplot as plt

alpha =  lr.intercept_[0]

Ym = predictYpolinomial(X, alpha, lr.coef_[0])

plt.scatter(X, Y)
plt.plot(X, Ym, color="red", linewidth=3)
plt.show()
# Out:
# 4

# %%
from sklearn.metrics import r2_score

r2 = r2_score(Y,Ym)
print('r2 score for perfect model is', r2)
# Out:
# r2 score for perfect model is 0.9999696376300696

# %% [markdown]
# ### e a base boston housing?

# %%
from sklearn.feature_selection import SelectFromModel

pf = PolynomialFeatures(degree=2)
Xp = pf.fit_transform(boston["data"])

print(Xp.shape)

lr = LinearRegression()
lr.fit(Xp, boston["target"])
print(lr.score(Xp, boston["target"]))
# Out:
# (506, 105)
# 0.923996655825981

# %%
sm = SelectFromModel(lr, threshold=10)
Xt = sm.fit_transform(Xp, boston["target"])

print(sm.estimator_.score(Xp, boston["target"]))
print(Xt.shape)
# Out:
# 0.923996655825981
# (506, 9)

# %%
Xo = sm.inverse_transform(Xt)
print(Xo.shape)
# Out:
# (506, 105)

# %% [markdown]
# ## Modelo Não-Linear

# %%
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

def func(x, a, b, c):
    return a * np.exp(-b * x) + c

X = np.linspace(0, 4, 50)
Y = func(X, 2.5, 1.3, 0.5)

rng = np.random.default_rng()

Y_noise = 0.2 * rng.normal(size=X.size)

Y = Y + Y_noise

# %%
popt, pcov = curve_fit(func, X, Y)

plt.scatter(X, Y)
plt.show()

# %%
popt, pcov = curve_fit(func, X, Y)
print(popt)
print(pcov)

Ym = func(X, *popt)
plt.scatter(X, Y,  label='data')
plt.plot(X, Ym, 'r-', label='fit: a=%5.3f, b=%5.3f, c=%5.3f' % tuple(popt))
plt.legend()
plt.show()
# Out:
# [2.59185253 1.18923626 0.46068042]
# [[ 0.0101508   0.00334891 -0.00074622]
#  [ 0.00334891  0.01118174  0.00405995]
#  [-0.00074622  0.00405995  0.0025108 ]]

# %%
from sklearn.metrics import r2_score
r2 = r2_score(Y,Ym)
print('r2 score for perfect model is', r2)
# Out:
# r2 score for perfect model is 0.9398473756860176

# %%
popt2, pcov2 = curve_fit(func, X, Y, bounds=(0, [3., 1., 0.5]))
print(popt2)
print(pcov2)

Ym = func(X, *popt)
Ym2 = func(X, *popt2)

plt.scatter(X, Y,  label='data')
plt.plot(X, Ym, 'r-', label='fit: a=%5.3f, b=%5.3f, c=%5.3f' % tuple(popt))
plt.plot(X, Ym2, 'g--', label='fit: a=%5.3f, b=%5.3f, c=%5.3f' % tuple(popt2))
plt.legend()
plt.show()
# Out:
# [2.5387304  1.         0.37982088]
# [[ 0.00982431  0.00180338 -0.00144257]
#  [ 0.00180338  0.00998077  0.00520201]
#  [-0.00144257  0.00520201  0.00397207]]

# %%
from sklearn.metrics import r2_score
r2 = r2_score(Y,Ym2)
print('r2 score for perfect model is', r2)
# Out:
# r2 score for perfect model is 0.9352212654661546
